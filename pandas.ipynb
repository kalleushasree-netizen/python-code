# %%
import pandas as pd
item = pd.read_csv('pandas_excel.csv')

# %%
print(item.groupby('category')["inventory_value"].max().idxmax())
# Out:
# Industrial

# %%
print(item.groupby('category')["avg_monthly_demand"].mean().idxmax())
# Out:
# Pharmaceutical

# %%
print(item.groupby('subcategory')["inventory_value"].sum().idxmax())
# Out:
# Electrical Parts

# %%
print(item.groupby('warehouse_zone')["inventory_value"].max().idxmax())
# Out:
# D1

# %%
print(item.groupby('supplier_id')["inventory_value"].mean().idxmax())
# Out:
# S1028

# %%
print(item.groupby('category')["stock_turnover_ratio"].mean().idxmax())
# Out:
# Pharmaceutical

# %%
print(item.groupby('category')["days_in_inventory"].max().idxmax())
# Out:
# Industrial

# %%
print(item.groupby('warehouse_zone')["stockout_frequency"].mean().idxmax())
# Out:
# B2

# %%
print(item.groupby('category')["days_in_inventory"].mean().idxmax())
# Out:
# Electronics

# %%
print(item.groupby('warehouse_zone')["stockout_frequency"].max().idxmax())
# Out:
# A1

# %%
print(item.groupby('supplier_id')["avg_lead_time_days"].max().idxmax())
# Out:
# S1001

# %%
print(item.groupby('item_id')["stock_turnover_ratio"].max().idxmax())
# Out:
# ITM00427

# %%
print(item.groupby('item_id')["excess_stock_level"].max().idxmax())
# Out:
# ITM01019

# %%
print(item.groupby('category')["holding_cost_per_unit"].mean().idxmax())
# Out:
# Industrial

# %%
print(item.groupby('category')["unit_cost"].mean().idxmax())
# Out:
# Industrial

# %%
print(item.groupby('supplier_id')["supplier_delay_incidents"].max().idxmax())
# Out:
# S1002

# %%
print(item.groupby('category')["stockout_frequency"].max().idxmax())
# Out:
# Apparel

# %%
print(item.groupby('warehouse_zone')["backorder_frequency"].max().idxmax())
# Out:
# C1

# %%
print(item.groupby('supplier_id')["backorder_frequency"].max().idxmax())
# Out:
# S1063

# %%
print(item.groupby('category')["excess_stock_level"].max().idxmax())
# Out:
# Grocery
