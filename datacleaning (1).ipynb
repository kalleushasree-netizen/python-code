# %%
import pandas as pd
df = pd.read_csv('finance_loan_portfolio_python_dataset.csv')

# %%
df.head()
# Out:
#    Record_ID Customer_ID    Customer_Name   Age  Gender     City  \
# 0  FIN-00255  CUST-00839      Arjun Gupta  64.0  Female   Jaipur
# 1  FIN-00474  CUST-00508       Rohan Iyer  63.0    Male   Mumbai
# 2  FIN-00725  CUST-00013     Rohan Jadhav  48.0  Female  Lucknow
# 3  FIN-00438  CUST-00328  Tanvi Chaudhary  56.0    Male   Nashik
# 4  FIN-00661  CUST-00740       Rahul Iyer  53.0  Female   Nashik
#
#        Employment_Type  Annual_Income_INR  Credit_Score      Loan_Type  ...  \
# 0        Self-Employed           679000.0         707.0      Home Loan  ...
# 1             Salaried          1275000.0         745.0  Personal Loan  ...
# 2  Government Employee          1390000.0         663.0  Personal Loan  ...
# 3  Government Employee           719000.0         695.0   Vehicle Loan  ...
# 4       Business Owner          7218000.0         665.0      Home Loan  ...
#
#    Late_Payment_Count  Default_Flag  Debt_to_Income_Ratio  \
# ...

# %%
df.isnull().sum()
# Out:
# Record_ID                   0
# Customer_ID                 0
# Customer_Name               0
# Age                        28
# Gender                     22
# City                       32
# Employment_Type            25
# Annual_Income_INR          34
# Credit_Score               42
# Loan_Type                   0
# Loan_Amount_INR             0
# Interest_Rate_Pct          18
# Loan_Term_Months            0
# Monthly_EMI_INR             0
# Disbursement_Date           0
# Outstanding_Balance_INR    24
# Payment_Status              0
# Days_Past_Due               0
# Late_Payment_Count          0
# Default_Flag                0
# Debt_to_Income_Ratio       35
# Savings_Balance_INR        31
# Investment_Value_INR       32
# Risk_Category               0
# Last_Payment_Date          27
# Payment_Mode               20
# Acquisition_Channel         0
# Branch_Name                 0
# dtype: int64

# %%
df["Age"] = df["Age"].fillna(df["Age"].mean())

# %%
df["Annual_Income_INR"] = df["Annual_Income_INR"].fillna(df["Annual_Income_INR"].mean())

# %%
df["Gender"]=df["Gender"].fillna("Unknown Gender")

# %%
df["City"]=df["City"].fillna("Unknown City")

# %%
df["Interest_Rate_Pct"] = df["Interest_Rate_Pct"].fillna(df["Interest_Rate_Pct"].mean())

# %%
df["Outstanding_Balance_INR"] =df["Outstanding_Balance_INR"].fillna(df["Outstanding_Balance_INR"].mean())

# %%
df["Debt_to_Income_Ratio"] =df["Debt_to_Income_Ratio"].fillna(df["Debt_to_Income_Ratio"].mean())

# %%
df["Savings_Balance_INR"] =df["Savings_Balance_INR"].fillna(df["Savings_Balance_INR"].mean())

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (1200, 28)

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male', 'Non-Binary', 'Unknown Gender'], dtype=object)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male              584
# Female            565
# Non-Binary         29
# Unknown Gender     22
# Name: count, dtype: int64

# %%
df.groupby("Gender")["Annual_Income_INR"].max()
# Out:
# Gender
# Female            7218000.0
# Male              7292000.0
# Non-Binary        4404000.0
# Unknown Gender    3652000.0
# Name: Annual_Income_INR, dtype: float64

# %%
df.groupby("Gender")["Loan_Amount_INR"].sum()
# Out:
# Gender
# Female             889915000
# Male              1038050000
# Non-Binary          43260000
# Unknown Gender      38810000
# Name: Loan_Amount_INR, dtype: int64

# %%
df.groupby(["Loan_Type","Risk_Category"])["Loan_Amount_INR"].sum().sort_values(ascending=False)
# Out:
# Loan_Type       Risk_Category
# Home Loan       Medium           410075000
#                 High             383155000
# Business Loan   Medium           203630000
# Vehicle Loan    Medium           144530000
# Home Loan       Low              144405000
# Vehicle Loan    Low              106720000
# Business Loan   High              87005000
# Personal Loan   Low               82290000
#                 Medium            78310000
# Vehicle Loan    High              71910000
# Education Loan  High              58830000
#                 Low               57480000
#                 Medium            53515000
# Business Loan   Low               48055000
# Gold Loan       Medium            33705000
# Personal Loan   High              26700000
# Gold Loan       Low               18480000
#                 High               1240000
# Name: Loan_Amount_INR, dtype: int64

# %%
df.groupby(["Loan_Type","Risk_Category"])["Loan_Amount_INR"].sum().sort_values(ascending=False)
# Out:
# Loan_Type       Risk_Category
# Home Loan       Medium           410075000
#                 High             383155000
# Business Loan   Medium           203630000
# Vehicle Loan    Medium           144530000
# Home Loan       Low              144405000
# Vehicle Loan    Low              106720000
# Business Loan   High              87005000
# Personal Loan   Low               82290000
#                 Medium            78310000
# Vehicle Loan    High              71910000
# Education Loan  High              58830000
#                 Low               57480000
#                 Medium            53515000
# Business Loan   Low               48055000
# Gold Loan       Medium            33705000
# Personal Loan   High              26700000
# Gold Loan       Low               18480000
#                 High               1240000
# Name: Loan_Amount_INR, dtype: int64

# %%
len(df)
# Out:
# 1200

# %%
df["Customer_ID"].nunique()
# Out:
# 653

# %%
(df["Customer_ID"].value_counts()>1).sum()
# Out:
# np.int64(351)

# %%
df["Loan_Type"].unique()
# Out:
# array(['Home Loan', 'Personal Loan', 'Vehicle Loan', 'Gold Loan',
#        'Education Loan', 'Business Loan'], dtype=object)

# %%
df.groupby("Loan_Type").size().sort_values(ascending=False)
# Out:
# Loan_Type
# Personal Loan     356
# Vehicle Loan      242
# Home Loan         204
# Business Loan     167
# Education Loan    120
# Gold Loan         111
# dtype: int64

# %%
df["Loan_Type"].value_counts()
# Out:
# Loan_Type
# Personal Loan     356
# Vehicle Loan      242
# Home Loan         204
# Business Loan     167
# Education Loan    120
# Gold Loan         111
# Name: count, dtype: int64

# %%
df.groupby("Payment_Status").size().sort_values(ascending=False)
# Out:
# Payment_Status
# On Time    389
# Closed     385
# Late       229
# Missed     197
# dtype: int64

# %%
df.groupby("Risk_Category").size().sort_values(ascending=False)
# Out:
# Risk_Category
# Medium    504
# Low       494
# High      202
# dtype: int64

# %%
df.groupby("City").size().sort_values(ascending=False).head(5)
# Out:
# City
# Mumbai       217
# Pune         166
# Bengaluru     85
# Delhi         81
# Thane         74
# dtype: int64

# %%
df.groupby("City")["Customer_ID"].nunique().sort_values(ascending=False)
# Out:
# City
# Mumbai          189
# Pune            152
# Bengaluru        81
# Delhi            78
# Thane            71
# Hyderabad        69
# Nagpur           60
# Chennai          57
# Nashik           57
# Surat            51
# Jaipur           48
# Kolkata          47
# Lucknow          47
# Ahmedabad        46
# Indore           45
# Unknown City     30
# Name: Customer_ID, dtype: int64

# %%
df.groupby("Employment_Type").size().sort_values(ascending=False)
# Out:
# Employment_Type
# Salaried               538
# Self-Employed          208
# Business Owner         168
# Freelancer             145
# Government Employee    116
# dtype: int64

# %%
df.groupby("Payment_Mode").size().sort_values(ascending=False)
# Out:
# Payment_Mode
# Auto-Debit     461
# UPI            311
# Net Banking    201
# Cheque         121
# Cash            86
# dtype: int64

# %%
df.groupby("Acquisition_Channel").size().sort_values(ascending=False)
# Out:
# Acquisition_Channel
# Mobile App              372
# Branch                  298
# Website                 261
# Partner                 151
# Relationship Manager    118
# dtype: int64

# %%
df.groupby("Branch_Name").size().sort_values(ascending=False).head(5)
# Out:
# Branch_Name
# Nagpur Civil Lines       134
# Nashik Road              130
# Pune Central             129
# Bengaluru MG Road        122
# Ahmedabad Navrangpura    120
# dtype: int64

# %%
df.groupby("Loan_Type")["Loan_Amount_INR"].sum().sort_values(ascending=False)
# Out:
# Loan_Type
# Home Loan         937635000
# Business Loan     338690000
# Vehicle Loan      323160000
# Personal Loan     187300000
# Education Loan    169825000
# Gold Loan          53425000
# Name: Loan_Amount_INR, dtype: int64

# %%
df.groupby("Loan_Type")["Loan_Amount_INR"].sum().sort_values(ascending=False).head(1)
# Out:
# Loan_Type
# Home Loan    937635000
# Name: Loan_Amount_INR, dtype: int64

# %%
df.groupby("Loan_Type")["Interest_Rate_Pct"].mean().sort_values(ascending=False)
# Out:
# Loan_Type
# Business Loan     16.910487
# Personal Loan     16.656390
# Gold Loan         13.607700
# Vehicle Loan      11.806721
# Education Loan    11.779373
# Home Loan          9.546699
# Name: Interest_Rate_Pct, dtype: float64

# %%
df.groupby("Loan_Type")["Monthly_EMI_INR"].mean().sort_values(ascending=False)
# Out:
# Loan_Type
# Business Loan     84940.635509
# Home Loan         58016.474657
# Gold Loan         36128.699459
# Vehicle Loan      34687.824545
# Education Loan    26300.832083
# Personal Loan     23593.630899
# Name: Monthly_EMI_INR, dtype: float64

# %%
df.groupby("Loan_Type")["Outstanding_Balance_INR"].mean().sort_values(ascending=False)
# Out:
# Loan_Type
# Home Loan         3.777620e+06
# Education Loan    9.177283e+05
# Business Loan     7.627392e+05
# Vehicle Loan      6.201863e+05
# Personal Loan     2.044419e+05
# Gold Loan         9.924024e+04
# Name: Outstanding_Balance_INR, dtype: float64

# %%
df.groupby("Payment_Status")["Outstanding_Balance_INR"].sum().sort_values(ascending=False)
# Out:
# Payment_Status
# Missed     4.395105e+08
# Late       4.060937e+08
# On Time    3.912443e+08
# Closed     5.172970e+06
# Name: Outstanding_Balance_INR, dtype: float64

# %%
df.groupby("Payment_Status")["Outstanding_Balance_INR"].mean().sort_values(ascending=False)
# Out:
# Payment_Status
# Missed     2.231018e+06
# Late       1.773335e+06
# On Time    1.005769e+06
# Closed     1.343629e+04
# Name: Outstanding_Balance_INR, dtype: float64

# %%
df.groupby("Loan_Type")["Credit_Score"].mean().sort_values(ascending=False)
# Out:
# Loan_Type
# Vehicle Loan      692.546610
# Personal Loan     684.046512
# Home Loan         682.393939
# Business Loan     681.080247
# Education Loan    680.468468
# Gold Loan         674.247706
# Name: Credit_Score, dtype: float64

# %%
df.groupby("Risk_Category")["Debt_to_Income_Ratio"].mean().sort_values(ascending=False)
# Out:
# Risk_Category
# High      0.762786
# Medium    0.627882
# Low       0.331235
# Name: Debt_to_Income_Ratio, dtype: float64

# %%
df.groupby("Risk_Category")[["Credit_Score","Annual_Income_INR","Loan_Amount_INR"]].mean()
# Out:
#                Credit_Score  Annual_Income_INR  Loan_Amount_INR
# Risk_Category
# High             635.340206       9.624176e+05     3.113069e+06
# Low              719.516736       1.698481e+06     9.259717e+05
# Medium           668.118852       1.263373e+06     1.832867e+06

# %%
df[df["Risk_Category"]=="High"].groupby("City").size().sort_values(ascending=False)
# Out:
# City
# Pune            38
# Mumbai          31
# Bengaluru       15
# Delhi           14
# Nashik          14
# Nagpur          13
# Chennai         12
# Lucknow         11
# Thane           10
# Indore           9
# Ahmedabad        7
# Kolkata          7
# Surat            7
# Jaipur           6
# Hyderabad        4
# Unknown City     4
# dtype: int64

# %%
df.groupby("Customer_ID")["Loan_Amount_INR"].sum().sort_values(ascending=False).head(10)
# Out:
# Customer_ID
# CUST-00049    16020000
# CUST-00539    14405000
# CUST-00873    13645000
# CUST-00174    13095000
# CUST-00223    12930000
# CUST-00318    12785000
# CUST-00528    12565000
# CUST-00217    12445000
# CUST-00267    12155000
# CUST-00867    12080000
# Name: Loan_Amount_INR, dtype: int64

# %%
df["Disbursement_Date"]=pd.to_datetime(df["Disbursement_Date"])

# %%
df["Last_Payment_Date"]=pd.to_datetime(df["Last_Payment_Date"])

# %%
df['Disbursement_Year']=df["Disbursement_Date"].dt.year

# %%
df['Disbursement_Month']=df["Disbursement_Date"].dt.month

# %%
loanpercent = (df["Loan_Type"].value_counts()/len(df))*100
print(loanpercent)
# Out:
# Loan_Type
# Personal Loan     29.666667
# Vehicle Loan      20.166667
# Home Loan         17.000000
# Business Loan     13.916667
# Education Loan    10.000000
# Gold Loan          9.250000
# Name: count, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1200 entries, 0 to 1229
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Record_ID                1200 non-null   object
#  1   Customer_ID              1200 non-null   object
#  2   Customer_Name            1200 non-null   object
#  3   Age                      1200 non-null   float64
#  4   Gender                   1200 non-null   object
#  5   City                     1200 non-null   object
#  6   Employment_Type          1175 non-null   object
#  7   Annual_Income_INR        1200 non-null   float64
#  8   Credit_Score             1160 non-null   float64
#  9   Loan_Type                1200 non-null   object
#  10  Loan_Amount_INR          1200 non-null   int64
#  11  Interest_Rate_Pct        1200 non-null   float64
#  12  Loan_Term_Months         1200 non-null   int64
#  13  Monthly_EMI_INR          1200 non-null   float64
# ...

# %%
plt.hist(df["Age"], bins=20)
plt.title("Histogram for Age")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
sns.histplot(df["Age"], kde=True)
plt.title("Histogram for Age")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
sns.countplot(x=df["Gender"])
plt.title("Count of Gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
count, bins, bars = plt.hist(df["Age"], bins=10)
for i in range(len(count)):
    plt.text(bins[i], count[i], int(count[i]))
plt.title("Histogram of Age")
plt.show()

# %%
sns.countplot(x=df["Loan_Type"], hue=df["Payment_Status"])
plt.title("Loan Type vs Payment Status")
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x=df["City"], hue=df["Annual_Income_INR"])
plt.title("City vs Annual Income")
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x=df["Default_Flag"], hue=df["Savings_Balance_INR"])
plt.title("Default Flag vs Savings Balance")
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x=df["Risk_Category"], hue=df["Payment_Mode"])
plt.title("Risk Category vs Payment Mode")
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=df["Gender"], y=df["Annual_Income_INR"])
plt.title("Gender vs Annual Income")
plt.xlabel("Gender")
plt.ylabel("Annual Income")
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=df["City"], y=df["Interest_Rate_Pct"])
plt.title("City vs Interest Rate")
plt.xlabel("Gender")
plt.ylabel("Annual Income")
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=df["Payment_Mode"], y=df["Payment_Status"])
plt.title("Payment Mode vs Payment Status")
plt.xlabel("Gender")
plt.ylabel("Annual Income")
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(x=df["Loan_Type"], y=df["Loan_Amount_INR"])
plt.title("Loan Type vs Loan Amount")
plt.xlabel("Loan Type")
plt.ylabel("Loan Amount")
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(x=df["Risk_Category"], y=df["Credit_Score"])
plt.title("Risk Category vs Credit Score")
plt.xlabel("Risk Category")
plt.ylabel("Credit Score")
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(x=df["Monthly_EMI_INR"], y=df["Employment_Type"])
plt.title("Monthly EMI vs Employment Type")
plt.xlabel("Monthly EMI")
plt.ylabel("Employment Type")
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(x=df["Annual_Income_INR"], y=df["Loan_Amount_INR"])
plt.title("Annual Income vs Loan Amount")
plt.xlabel("Annual Income")
plt.ylabel("Loan Amount")
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(x=df["Gender"], y=df["Payment_Mode"])
plt.title("Gender vs Payment Mode")
plt.xlabel("Gender")
plt.ylabel("Payment Mode")
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(x=df["Annual_Income_INR"], y=df["Branch_Name"])
plt.title("Annual Income vs Branch Name")
plt.xlabel("Annual Income")
plt.ylabel("Branch Name")
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(x=df["Default_Flag"], y=df["Debt_to_Income_Ratio"])
plt.title("Default Flag vs Debt to Income")
plt.xlabel("Default Flag")
plt.ylabel("Debt to Income")
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(x=df["Annual_Income_INR"], y=df["Loan_Amount_INR"], hue=df["Loan_Type"])
plt.title("Annual Income vs Loan Amount as per Loan Type")
plt.xlabel("Annual Income")
plt.ylabel("Loan Amount")
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(x=df["Loan_Term_Months"], y=df["Outstanding_Balance_INR"], hue=df["Loan_Type"])
plt.title("Loan Term vs Outstanding Balance as per Loan Type")
plt.xlabel("Loan Term")
plt.ylabel("Outstanding Balance")
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(x=df["Loan_Term_Months"], y=df["Disbursement_Month"], hue=df["Gender"])
plt.title("Loan Term vs Disbursement Month as per Loan Type")
plt.xlabel("Loan Term")
plt.ylabel("Disbursement Month")
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(x=df["Savings_Balance_INR"], y=df["Acquisition_Channel"], hue=df["Loan_Type"])
plt.title("Savings Balance vs Acquisition Channel as per Loan Type")
plt.xlabel("Annual Income")
plt.ylabel("Loan Amount")
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=df["Gender"], y=df["Annual_Income_INR"], hue=df["Risk_Category"],errorbar= None)
plt.title("Gender vs Annual Income as per Risk Category")
plt.xlabel("Gender")
plt.ylabel("Annual Income")
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=df["City"], y=df["Disbursement_Date"], hue=df["Risk_Category"],errorbar= None)
plt.title("Gender vs Disbursement Date as per Risk Category")
plt.xlabel("Gender")
plt.ylabel("Annual Income")
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=df["Loan_Amount_INR"], y=df["Late_Payment_Count"], hue=df["Age"],errorbar= None)
plt.title("Loan Amount vs Late Payment Count as per Age")
plt.xlabel("Loan Amount")
plt.ylabel("Late Payment Count")
plt.xticks(rotation=90)
plt.show()
